# %%
# Imports

import os
import requests
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display
from openai import OpenAI

# %%
openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')

message = "Hello, Llama! This is my first ever message to you! Hi!"
response = openai.chat.completions.create(model="llama3.2", messages=[{"role":"user", "content":message}])
print(response.choices[0].message.content)
# Out:
# Hello! Welcome to our conversation! I'm excited to be chatting with you, especially since it's your first message to me! I'm here to help answer any questions, provide information, or just have a friendly conversation. How's your day going so far?

# %%
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:

    def __init__(self, url):
        """
        Create this Website object from the given url using the BeautifulSoup library
        """
        self.url = url
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        for irrelevant in soup.body(["script", "style", "img", "input"]):
            irrelevant.decompose()
        self.text = soup.body.get_text(separator="\n", strip=True)

# %%
ed = Website("https://metricool.com/")
print(ed.title)
print(ed.text)
# Out:
# METRICOOL ▷ Social Media Management Tool
# Short video in 2026: Instagram vs. TikTok vs. YouTube [Report] ➔
# Product
# Reporting
# Metricool Studio
# Campaign Dashboard
# Reports
# Looker Studio
# Hashtag Tracker
# Planner & execution
# Planner
# Approval System
# SmartLinks
# Artificial Intelligence Assistant
# Inbox
# Measure & Grow
# Analytics
# Competitors
# Ads
# Integrations
# Product Updates
# Metricool MCP
# Social Media
# Instagram
# TikTok
# YouTube
# Threads
# Twitter
# Twitch
# Google Business Profile
# Bluesky
# Facebook
# Pinterest
# LinkedIn
# Pricing
# Agencies
# Metrischool
# Courses
# Metricool Expert Certification
# Social Media School
# YouTube Ads Bootcamp
# TikTokSchool
# AI Social Media Marketing Course
# Resources
# Tutorials
# Resources
# Studies
# Masterclass
# News
# Blog
# Newsletter
# en
# es
# fr
# de
# it
# nl
# pt
# Login
# Sign up here
# Sign up here
# Everything flows better when your content, data, and team are all in the same tab
# Plan, measure, and manage it all in one tool that saves time and gives you full control over your social media.
# Create your free account
# Google, Pinterest, Meta, LinkedIn and X partner
# Trusted by teams at
# Every week,
# thousands of Social Media Managers
# get
# 12 hours of their life back
# By trading the chaos of endless tabs and windows for a clean, organized workspace
# Plan smarter
# Drag and drop content into the calendar
# , preview how it’ll look on each platform, and simplify workflow to
# reach more people without the stress
# .
# Automate the boring stuff
# Reports generate themselves
# , saved replies go out with one click, and recurring posts are handled with templates.
# Analyze with clear data
# The
# metrics that matter are always right there
# . No digging, no guessing, no wasted time.
# “
# A social media manager’s best friend for 3 years already”
# (Linda. L.)
# Recognized on G2 by the social media professionals that  use Metricool every day
# Create your free account
# A management tool as human as you are
# Behind every social media account, there’s a person trying to work their magic around the clock. That’s why we built a
# dashboard with advanced features to make your job easier without the hassle
# .
# Planner
# Analytics
# Reporting
# Inbox
# Smartlinks
# Campaigns
# 3-in-1
# Planner, assistant, and calendar
# Drag and drop content into the calendar, find the best times to post, schedule across all your networks, or build automated content lists. Need a hand? Our AI social media assistant is ready to spark ideas. It’s that simple.
# Explore the Planner
# Measure
# Analytics (without the headache)
# Turn data into smart decisions. See how your social channels are performing, track your progress over time, and keep an eye on the competition at a glance. No number crunching, no fuss.
# Explore Analytics
# ANALYZE
# Reporting (for when the data doesn’t speak for itself)
# The numbers are there. The challenge is the time it takes to turn them into something useful. Metricool does it for you: automated reports, AI analysis, campaign dashboards, and Looker Studio connection.
# Explore Reporting
# Reply
# Inbox (that lets you breathe)
# All your messages and comments, neatly in one place. Reply without the stress and never miss an important conversation.
# Explore the Inbox
# Connect
# Smartlinks (to turn likes into customers)
# Create as many link in bios as you need, customize them your way, and track results in real time. Turn every click into an opportunity.
# Explore Smartlinks
# Promote
# Unified Ads Campaigns
# Manage your Google, Facebook, and TikTok Ads from one single dashboard. Create, analyze, and fine-tune your campaigns without jumping between platforms.
# Explore Ads
# Backed by the big names
# Everything you need in one dashboard
# Less chaos, more control. Metricool brings together everything you need to manage your social media without wasting time.
# 01
# Create content without writers’ block
# Use the AI assistant and say goodbye to blank pages.
# 02
# Work as a unified team
# Assign roles and use the approval system with clients.
# 03
# Post at the perfect time
# With the best hours and hashtags that reach your audience.
# 04
# Save and organize your content
# With a media library always within reach.
# 05
# Generate reports in minutes
# No spreadsheets, no complications.
# Get started with your FREE account
# Metricool’s best-kept secret
# When you need a hand, just reach out. We’re here, right on the other side of the screen. Real people helping real people.
# FREQUENTLY ASKED QUESTIONS
# Can I cancel my paid subscription at any time?
# Yes. You can cancel your plan at any time. You can continue to enjoy your payment plan until the end of the current billing cycle. Once it is terminated, your account will become free.
# Can the plan be extended at any time?
# If you want to upgrade your plan, you can do so anytime. The paid and unused portion of the previous plan will be deducted from the price of the new plan.
# Is it possible to connect several Google Business Profiles under the same brand?
# Each Metricool brand corresponds to a single location, so you’ll need a separate brand for each Google Business Profile. This allows you to schedule tailored content and track performance independently for each location. If you want combined reports across multiple brands, you can do this using the Looker Studio Connector (available on the Advanced Plan), which lets you include data from several brands in a single custom report.
# What is a brand in Metricool?
# Each brand in Metricool represents a business, brand, or customer. Under each brand, you can manage 1 profile for each social network or ad platform.
# What are the main differences between a STARTER and ADVANCED plan?
# The
# ADVANCED plan
# offers everything in the Starter plan, plus additional features to manage more brands and streamline your workflow:
# Collaborators:
# Give clients or team members access to a specific brand without exposing data from others.
# Looker Studio & API access:
# Create in-depth, customized reports and connect Metricool with other tools.
# Custom report templates:
# Design reports that fit your needs and branding.
# Zapier integration:
# Automate processes and save time on repetitive tasks.
# Is Metricool free?
# Yes! You can use Metricool for free, forever. With our Free plan, you can connect 1 brand associated to a profile for each social network, plan your content, publish content automatically, manage messages from your networks, and more.
# Can I downgrade my current subscription?
# Yes. You can switch to a lower plan at any time, and the change will take effect at the end of your current billing period.
# Where can I download my invoices?
# Invoices are automatically generated once payment by card or PayPal has been made. They can be downloaded from your account settings. It can also be set up to automatically, so you receive them in your email.
# Your social media partner, always by your side
# Join over 3.5 million professionals who use Metricool
# Download our app
# Google Play
# Download our app
# Apple Store
# Product
# Best time to post on social networks
# Schedule Instagram
# Schedule X (Twitter) posts
# Schedule TikTok videos
# Schedule Facebook posts
# Schedule YouTube Videos
# Chrome Extension
# Product updates
# Integrations
# Resources
# Metricool: Mega tutorial
# Free social media tools
# 2026 US Calendar for SMM
# 2026 UK Calendar for SMM
# Newsroom
# Integrators
# White Label
# Autolists
# Resource center
# Newsletter
# Comparison Metricool
# Studies
# 2026 YouTube Study
# 2026 Instagram Study
# 2026 TikTok Study
# 2026 LinkedIn Study
# 2026 Well-Being in Social Media
# 2026 Social Media Study
# 2026 Use of AI in Social Media
# 2025 Social Ads Study
# 2025 Short-Form Video Study
# 2025 Instagram Content Playbook
# Company
# Contact
# Affiliate Program
# Reviews
# Careers
# About us
# Terms & Conditions
# Privacy Policy
# Cookies Policy
# Legal Notice
# Whistleblower Channel
